# %%
import tarfile
from pathlib import Path

# ===== 설정 =====
base_dir = Path("/Users/seowonchoi/Documents/NAPPL/Operation/data/upgrade-camera/0206")

processed_count = 0
renamed_count = 0

print(f"Scanning directory: {base_dir}\n")

# =========================================================
# 1️⃣ Extract .raw from each tar.gz
# =========================================================
for tar_path in sorted(base_dir.glob("*.tar.gz")):
    print(f"Processing: {tar_path.name}")

    try:
        with tarfile.open(tar_path, "r:gz") as tar:
            members = tar.getmembers()
            raw_members = [m for m in members if m.name.endswith(".raw")]

            if len(raw_members) != 1:
                print(f"    ⚠ Warning: found {len(raw_members)} .raw files")
                continue

            raw_member = raw_members[0]
            out_path = base_dir / Path(raw_member.name).name

            if out_path.exists():
                print(f"    ⚠ Skipping (already exists): {out_path.name}")
                continue

            with tar.extractfile(raw_member) as f_in, open(out_path, "wb") as f_out:
                f_out.write(f_in.read())

            print(f"    Extracted: {out_path.name}")

        # delete tar.gz after successful extraction
        tar_path.unlink()
        print(f"    Deleted: {tar_path.name}")
        processed_count += 1

    except Exception as e:
        print(f"    ❌ Error processing {tar_path.name}: {e}")

# =========================================================
# 2️⃣ Rename LOG.raw → LOG.log
# =========================================================
print("\nRenaming LOG files...\n")

for raw_path in base_dir.glob("*.raw"):
    if "log" in raw_path.name.lower():
        new_path = raw_path.with_suffix(".log")

        if new_path.exists():
            print(f"    ⚠ Skip rename (target exists): {new_path.name}")
            continue

        raw_path.rename(new_path)
        print(f"    Renamed: {raw_path.name} → {new_path.name}")
        renamed_count += 1

# =========================================================
# Summary
# =========================================================
print("\n======================================")
print(f"Done.")
print(f"Extracted files : {processed_count}")
print(f"Renamed files   : {renamed_count}")
print("======================================")
# Out:
# Scanning directory: /Users/seowonchoi/Documents/NAPPL/Operation/data/upgrade-camera/0206
#
# Processing: Camera-LOG-String87_FreezeInRuns_Quad6plus_run32.tar.gz
#     Extracted: Camera-LOG-String87_FreezeInRuns_Quad6plus_run32.raw
#     Deleted: Camera-LOG-String87_FreezeInRuns_Quad6plus_run32.tar.gz
# Processing: Camera-Run_IA_string89_mDOM_port5130_cam1_illum0_gain0_exposure3700ms_20260206-21-41-59_trial0_new.tar.gz
#     Extracted: Camera-Run_IA_string89_mDOM_port5130_cam1_illum0_gain0_exposure3700ms_20260206-21-41-59_trial0_new.raw
#     Deleted: Camera-Run_IA_string89_mDOM_port5130_cam1_illum0_gain0_exposure3700ms_20260206-21-41-59_trial0_new.tar.gz
# Processing: Camera-Run_IA_string89_mDOM_port5234_cam1_illum0_gain0_exposure3700ms_20260206-21-41-59_trial0_new.tar.gz
#     Extracted: Camera-Run_IA_string89_mDOM_port5234_cam1_illum0_gain0_exposure3700ms_20260206-21-41-59_trial0_new.raw
#     Deleted: Camera-Run_IA_string89_mDOM_port5234_cam1_illum0_gain0_exposure3700ms_20260206-21-41-59_trial0_new.tar.gz
# Processing: Camera-Run_IA_string90_mDOM_port5146_cam1_illum0_gain0_exposure3700ms_20260206-21-41-55_trial0_new.tar.gz
#     Extracted: Camera-Run_IA_string90_mDOM_port5146_cam1_illum0_gain0_exposure3700ms_20260206-21-41-55_trial0_new.raw
#     Deleted: Camera-Run_IA_string90_mDOM_port5146_cam1_illum0_gain0_exposure3700ms_20260206-21-41-55_trial0_new.tar.gz
# Processing: Camera-Run_IA_string91_mDOM_port5082_cam1_illum0_gain0_exposure3700ms_20260206-21-42-02_trial0_new.tar.gz
#     Extracted: Camera-Run_IA_string91_mDOM_port5082_cam1_illum0_gain0_exposure3700ms_20260206-21-42-02_trial0_new.raw
#     Deleted: Camera-Run_IA_string91_mDOM_port5082_cam1_illum0_gain0_exposure3700ms_20260206-21-42-02_trial0_new.tar.gz
# Processing: Camera-Run_IA_string92_mDOM_port5218_cam1_illum0_gain0_exposure3700ms_20260206-21-41-51_trial0_new.tar.gz
#     Extracted: Camera-Run_IA_string92_mDOM_port5218_cam1_illum0_gain0_exposure3700ms_20260206-21-41-51_trial0_new.raw
#     Deleted: Camera-Run_IA_string92_mDOM_port5218_cam1_illum0_gain0_exposure3700ms_20260206-21-41-51_trial0_new.tar.gz
# Processing: Camera-Run_IB_string88_mDOM_port5319_cam2_illum4_gain0_exposure3700ms_20260206-21-41-50_trial0_new.tar.gz
#     Extracted: Camera-Run_IB_string88_mDOM_port5319_cam2_illum4_gain0_exposure3700ms_20260206-21-41-50_trial0_new.raw
#     Deleted: Camera-Run_IB_string88_mDOM_port5319_cam2_illum4_gain0_exposure3700ms_20260206-21-41-50_trial0_new.tar.gz
# Processing: Camera-Run_IB_string89_mDOM_port5127_cam2_illum4_gain0_exposure3700ms_20260206-21-41-59_trial0_new.tar.gz
#     Extracted: Camera-Run_IB_string89_mDOM_port5127_cam2_illum4_gain0_exposure3700ms_20260206-21-41-59_trial0_new.raw
#     Deleted: Camera-Run_IB_string89_mDOM_port5127_cam2_illum4_gain0_exposure3700ms_20260206-21-41-59_trial0_new.tar.gz
# Processing: Camera-Run_IB_string91_mDOM_port5143_cam2_illum4_gain0_exposure3700ms_20260206-21-42-04_trial0_new.tar.gz
#     Extracted: Camera-Run_IB_string91_mDOM_port5143_cam2_illum4_gain0_exposure3700ms_20260206-21-42-04_trial0_new.raw
#     Deleted: Camera-Run_IB_string91_mDOM_port5143_cam2_illum4_gain0_exposure3700ms_20260206-21-42-04_trial0_new.tar.gz
# Processing: Camera-Run_IB_string91_mDOM_port5271_cam2_illum4_gain0_exposure3700ms_20260206-21-42-38_trial0_new.tar.gz
#     Extracted: Camera-Run_IB_string91_mDOM_port5271_cam2_illum4_gain0_exposure3700ms_20260206-21-42-38_trial0_new.raw
#     Deleted: Camera-Run_IB_string91_mDOM_port5271_cam2_illum4_gain0_exposure3700ms_20260206-21-42-38_trial0_new.tar.gz
# Processing: Camera-Run_IB_string91_mDOM_port5295_cam2_illum4_gain0_exposure3700ms_20260206-21-42-01_trial0_new.tar.gz
#     Extracted: Camera-Run_IB_string91_mDOM_port5295_cam2_illum4_gain0_exposure3700ms_20260206-21-42-01_trial0_new.raw
#     Deleted: Camera-Run_IB_string91_mDOM_port5295_cam2_illum4_gain0_exposure3700ms_20260206-21-42-01_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string87_mDOM_port5159_cam1_illum1_gain0_exposure3700ms_20260206-21-43-17_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string87_mDOM_port5159_cam1_illum1_gain0_exposure3700ms_20260206-21-43-17_trial0_new.raw
#     Deleted: Camera-Run_IIB_string87_mDOM_port5159_cam1_illum1_gain0_exposure3700ms_20260206-21-43-17_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string89_mDOM_port5111_cam1_illum1_gain0_exposure3700ms_20260206-21-43-36_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string89_mDOM_port5111_cam1_illum1_gain0_exposure3700ms_20260206-21-43-36_trial0_new.raw
#     Deleted: Camera-Run_IIB_string89_mDOM_port5111_cam1_illum1_gain0_exposure3700ms_20260206-21-43-36_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string89_mDOM_port5127_cam1_illum1_gain0_exposure3700ms_20260206-21-43-40_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string89_mDOM_port5127_cam1_illum1_gain0_exposure3700ms_20260206-21-43-40_trial0_new.raw
#     Deleted: Camera-Run_IIB_string89_mDOM_port5127_cam1_illum1_gain0_exposure3700ms_20260206-21-43-40_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string89_mDOM_port5319_cam1_illum1_gain0_exposure3700ms_20260206-21-43-41_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string89_mDOM_port5319_cam1_illum1_gain0_exposure3700ms_20260206-21-43-41_trial0_new.raw
#     Deleted: Camera-Run_IIB_string89_mDOM_port5319_cam1_illum1_gain0_exposure3700ms_20260206-21-43-41_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string90_mDOM_port5106_cam1_illum1_gain0_exposure3700ms_20260206-21-44-47_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string90_mDOM_port5106_cam1_illum1_gain0_exposure3700ms_20260206-21-44-47_trial0_new.raw
#     Deleted: Camera-Run_IIB_string90_mDOM_port5106_cam1_illum1_gain0_exposure3700ms_20260206-21-44-47_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string90_mDOM_port5122_cam1_illum1_gain0_exposure3700ms_20260206-21-44-12_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string90_mDOM_port5122_cam1_illum1_gain0_exposure3700ms_20260206-21-44-12_trial0_new.raw
#     Deleted: Camera-Run_IIB_string90_mDOM_port5122_cam1_illum1_gain0_exposure3700ms_20260206-21-44-12_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string90_mDOM_port5146_cam1_illum1_gain0_exposure3700ms_20260206-21-43-31_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string90_mDOM_port5146_cam1_illum1_gain0_exposure3700ms_20260206-21-43-31_trial0_new.raw
#     Deleted: Camera-Run_IIB_string90_mDOM_port5146_cam1_illum1_gain0_exposure3700ms_20260206-21-43-31_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string90_mDOM_port5306_cam1_illum1_gain0_exposure3700ms_20260206-21-43-32_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string90_mDOM_port5306_cam1_illum1_gain0_exposure3700ms_20260206-21-43-32_trial0_new.raw
#     Deleted: Camera-Run_IIB_string90_mDOM_port5306_cam1_illum1_gain0_exposure3700ms_20260206-21-43-32_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string91_mDOM_port5138_cam1_illum1_gain0_exposure3700ms_20260206-21-45-02_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string91_mDOM_port5138_cam1_illum1_gain0_exposure3700ms_20260206-21-45-02_trial0_new.raw
#     Deleted: Camera-Run_IIB_string91_mDOM_port5138_cam1_illum1_gain0_exposure3700ms_20260206-21-45-02_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string91_mDOM_port5191_cam1_illum1_gain0_exposure3700ms_20260206-21-43-40_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string91_mDOM_port5191_cam1_illum1_gain0_exposure3700ms_20260206-21-43-40_trial0_new.raw
#     Deleted: Camera-Run_IIB_string91_mDOM_port5191_cam1_illum1_gain0_exposure3700ms_20260206-21-43-40_trial0_new.tar.gz
# Processing: Camera-Run_IIB_string91_mDOM_port5319_cam1_illum1_gain0_exposure3700ms_20260206-21-43-42_trial0_new.tar.gz
#     Extracted: Camera-Run_IIB_string91_mDOM_port5319_cam1_illum1_gain0_exposure3700ms_20260206-21-43-42_trial0_new.raw
#     Deleted: Camera-Run_IIB_string91_mDOM_port5319_cam1_illum1_gain0_exposure3700ms_20260206-21-43-42_trial0_new.tar.gz
# Processing: Camera-Run_IIIA2_string89_mDOM_port5162_cam1_illum0_gain0_exposure3700ms_20260206-21-46-18_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIA2_string89_mDOM_port5162_cam1_illum0_gain0_exposure3700ms_20260206-21-46-18_trial0_new.raw
#     Deleted: Camera-Run_IIIA2_string89_mDOM_port5162_cam1_illum0_gain0_exposure3700ms_20260206-21-46-18_trial0_new.tar.gz
# Processing: Camera-Run_IIIA2_string91_mDOM_port5290_cam1_illum0_gain0_exposure3700ms_20260206-21-46-47_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIA2_string91_mDOM_port5290_cam1_illum0_gain0_exposure3700ms_20260206-21-46-47_trial0_new.raw
#     Deleted: Camera-Run_IIIA2_string91_mDOM_port5290_cam1_illum0_gain0_exposure3700ms_20260206-21-46-47_trial0_new.tar.gz
# Processing: Camera-Run_IIIA_string87_mDOM_port5114_cam1_illum0_gain0_exposure3700ms_20260206-21-46-44_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIA_string87_mDOM_port5114_cam1_illum0_gain0_exposure3700ms_20260206-21-46-44_trial0_new.raw
#     Deleted: Camera-Run_IIIA_string87_mDOM_port5114_cam1_illum0_gain0_exposure3700ms_20260206-21-46-44_trial0_new.tar.gz
# Processing: Camera-Run_IIIA_string90_mDOM_port5098_cam1_illum0_gain0_exposure3700ms_20260206-21-47-03_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIA_string90_mDOM_port5098_cam1_illum0_gain0_exposure3700ms_20260206-21-47-03_trial0_new.raw
#     Deleted: Camera-Run_IIIA_string90_mDOM_port5098_cam1_illum0_gain0_exposure3700ms_20260206-21-47-03_trial0_new.tar.gz
# Processing: Camera-Run_IIIA_string90_mDOM_port5106_cam1_illum0_gain0_exposure3700ms_20260206-21-47-33_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIA_string90_mDOM_port5106_cam1_illum0_gain0_exposure3700ms_20260206-21-47-33_trial0_new.raw
#     Deleted: Camera-Run_IIIA_string90_mDOM_port5106_cam1_illum0_gain0_exposure3700ms_20260206-21-47-33_trial0_new.tar.gz
# Processing: Camera-Run_IIIA_string90_mDOM_port5130_cam1_illum0_gain0_exposure3700ms_20260206-21-47-05_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIA_string90_mDOM_port5130_cam1_illum0_gain0_exposure3700ms_20260206-21-47-05_trial0_new.raw
#     Deleted: Camera-Run_IIIA_string90_mDOM_port5130_cam1_illum0_gain0_exposure3700ms_20260206-21-47-05_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string87_mDOM_port5175_cam3_illum3_gain0_exposure3700ms_20260206-21-47-59_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string87_mDOM_port5175_cam3_illum3_gain0_exposure3700ms_20260206-21-47-59_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string87_mDOM_port5175_cam3_illum3_gain0_exposure3700ms_20260206-21-47-59_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string87_mDOM_port5282_cam3_illum3_gain0_exposure3700ms_20260206-21-49-08_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string87_mDOM_port5282_cam3_illum3_gain0_exposure3700ms_20260206-21-49-08_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string87_mDOM_port5282_cam3_illum3_gain0_exposure3700ms_20260206-21-49-08_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string88_mDOM_port5167_cam3_illum3_gain0_exposure3700ms_20260206-21-48-38_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string88_mDOM_port5167_cam3_illum3_gain0_exposure3700ms_20260206-21-48-38_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string88_mDOM_port5167_cam3_illum3_gain0_exposure3700ms_20260206-21-48-38_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string88_mDOM_port5194_cam3_illum3_gain0_exposure3700ms_20260206-21-49-45_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string88_mDOM_port5194_cam3_illum3_gain0_exposure3700ms_20260206-21-49-45_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string88_mDOM_port5194_cam3_illum3_gain0_exposure3700ms_20260206-21-49-45_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string88_mDOM_port5274_cam3_illum3_gain0_exposure3700ms_20260206-21-48-41_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string88_mDOM_port5274_cam3_illum3_gain0_exposure3700ms_20260206-21-48-41_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string88_mDOM_port5274_cam3_illum3_gain0_exposure3700ms_20260206-21-48-41_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string90_mDOM_port5162_cam3_illum3_gain0_exposure3700ms_20260206-21-49-58_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string90_mDOM_port5162_cam3_illum3_gain0_exposure3700ms_20260206-21-49-58_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string90_mDOM_port5162_cam3_illum3_gain0_exposure3700ms_20260206-21-49-58_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string90_mDOM_port5175_cam3_illum3_gain0_exposure3700ms_20260206-21-48-19_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string90_mDOM_port5175_cam3_illum3_gain0_exposure3700ms_20260206-21-48-19_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string90_mDOM_port5175_cam3_illum3_gain0_exposure3700ms_20260206-21-48-19_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string91_mDOM_port5162_cam3_illum3_gain0_exposure3700ms_20260206-21-48-44_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string91_mDOM_port5162_cam3_illum3_gain0_exposure3700ms_20260206-21-48-44_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string91_mDOM_port5162_cam3_illum3_gain0_exposure3700ms_20260206-21-48-44_trial0_new.tar.gz
# Processing: Camera-Run_IIIB2_string92_mDOM_port5146_cam3_illum3_gain0_exposure3700ms_20260206-21-46-27_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB2_string92_mDOM_port5146_cam3_illum3_gain0_exposure3700ms_20260206-21-46-27_trial0_new.raw
#     Deleted: Camera-Run_IIIB2_string92_mDOM_port5146_cam3_illum3_gain0_exposure3700ms_20260206-21-46-27_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string89_mDOM_port5098_cam2_illum2_gain0_exposure3700ms_20260206-21-53-50_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string89_mDOM_port5098_cam2_illum2_gain0_exposure3700ms_20260206-21-53-50_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string89_mDOM_port5098_cam2_illum2_gain0_exposure3700ms_20260206-21-53-50_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string89_mDOM_port5111_cam2_illum2_gain0_exposure3700ms_20260206-21-52-21_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string89_mDOM_port5111_cam2_illum2_gain0_exposure3700ms_20260206-21-52-21_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string89_mDOM_port5111_cam2_illum2_gain0_exposure3700ms_20260206-21-52-21_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string89_mDOM_port5154_cam2_illum2_gain0_exposure3700ms_20260206-21-52-53_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string89_mDOM_port5154_cam2_illum2_gain0_exposure3700ms_20260206-21-52-53_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string89_mDOM_port5154_cam2_illum2_gain0_exposure3700ms_20260206-21-52-53_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string89_mDOM_port5170_cam2_illum2_gain0_exposure3700ms_20260206-21-53-19_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string89_mDOM_port5170_cam2_illum2_gain0_exposure3700ms_20260206-21-53-19_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string89_mDOM_port5170_cam2_illum2_gain0_exposure3700ms_20260206-21-53-19_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string89_mDOM_port5175_cam2_illum2_gain0_exposure3700ms_20260206-21-52-15_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string89_mDOM_port5175_cam2_illum2_gain0_exposure3700ms_20260206-21-52-15_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string89_mDOM_port5175_cam2_illum2_gain0_exposure3700ms_20260206-21-52-15_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string90_mDOM_port5111_cam2_illum2_gain0_exposure3700ms_20260206-21-50-46_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string90_mDOM_port5111_cam2_illum2_gain0_exposure3700ms_20260206-21-50-46_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string90_mDOM_port5111_cam2_illum2_gain0_exposure3700ms_20260206-21-50-46_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string90_mDOM_port5167_cam2_illum2_gain0_exposure3700ms_20260206-21-50-41_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string90_mDOM_port5167_cam2_illum2_gain0_exposure3700ms_20260206-21-50-41_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string90_mDOM_port5167_cam2_illum2_gain0_exposure3700ms_20260206-21-50-41_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string90_mDOM_port5274_cam2_illum2_gain0_exposure3700ms_20260206-21-50-44_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string90_mDOM_port5274_cam2_illum2_gain0_exposure3700ms_20260206-21-50-44_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string90_mDOM_port5274_cam2_illum2_gain0_exposure3700ms_20260206-21-50-44_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string91_mDOM_port5106_cam2_illum2_gain0_exposure3700ms_20260206-21-52-24_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string91_mDOM_port5106_cam2_illum2_gain0_exposure3700ms_20260206-21-52-24_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string91_mDOM_port5106_cam2_illum2_gain0_exposure3700ms_20260206-21-52-24_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string91_mDOM_port5122_cam2_illum2_gain0_exposure3700ms_20260206-21-51-46_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string91_mDOM_port5122_cam2_illum2_gain0_exposure3700ms_20260206-21-51-46_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string91_mDOM_port5122_cam2_illum2_gain0_exposure3700ms_20260206-21-51-46_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string91_mDOM_port5154_cam2_illum2_gain0_exposure3700ms_20260206-21-51-47_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string91_mDOM_port5154_cam2_illum2_gain0_exposure3700ms_20260206-21-51-47_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string91_mDOM_port5154_cam2_illum2_gain0_exposure3700ms_20260206-21-51-47_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string91_mDOM_port5290_cam2_illum2_gain0_exposure3700ms_20260206-21-52-22_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string91_mDOM_port5290_cam2_illum2_gain0_exposure3700ms_20260206-21-52-22_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string91_mDOM_port5290_cam2_illum2_gain0_exposure3700ms_20260206-21-52-22_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string91_mDOM_port5306_cam2_illum2_gain0_exposure3700ms_20260206-21-51-16_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string91_mDOM_port5306_cam2_illum2_gain0_exposure3700ms_20260206-21-51-16_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string91_mDOM_port5306_cam2_illum2_gain0_exposure3700ms_20260206-21-51-16_trial0_new.tar.gz
# Processing: Camera-Run_IIIB_string92_mDOM_port5159_cam2_illum2_gain0_exposure3700ms_20260206-21-48-06_trial0_new.tar.gz
#     Extracted: Camera-Run_IIIB_string92_mDOM_port5159_cam2_illum2_gain0_exposure3700ms_20260206-21-48-06_trial0_new.raw
#     Deleted: Camera-Run_IIIB_string92_mDOM_port5159_cam2_illum2_gain0_exposure3700ms_20260206-21-48-06_trial0_new.tar.gz
#
# Renaming LOG files...
#
#     Renamed: Camera-LOG-String87_FreezeInRuns_Quad6plus_run32.raw → Camera-LOG-String87_FreezeInRuns_Quad6plus_run32.log
#
# ======================================
# Done.
# Extracted files : 51
# Renamed files   : 1
# ======================================
